# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
#!unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    transform = transforms.Compose(
      [transforms.Resize(image_size),                    
      transforms.ToTensor()
      ])

    data = datasets.ImageFolder(data_dir, transform=transform)
    dataloader = torch.utils.data.DataLoader (data, batch_size=batch_size, shuffle=True)
    return dataloader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 128
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
from sklearn.preprocessing import MaxAbsScaler
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min,max= feature_range
    x = x*(max-min) +min
  
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9608)
# Max:  tensor(0.7490)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim=conv_dim
        
        self.conv1 = nn.Conv2d(3,conv_dim,kernel_size = 4, stride=2,padding=1)
        self.conv2 = nn.Conv2d(conv_dim,conv_dim*2,kernel_size = 4, stride=2,padding=1)
        self.batch2 = nn.BatchNorm2d(conv_dim*2)
        self.conv3 = nn.Conv2d(conv_dim*2,conv_dim*4,kernel_size = 4, stride=2,padding=1)
        self.batch3 = nn.BatchNorm2d(conv_dim*4)
        self.fc = nn.Linear(conv_dim*4*4*4,1)
        
    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        x = F.leaky_relu(self.conv1(x),0.2)
        x = self.conv2(x)
        x = F.leaky_relu(self.batch2(x),0.2)
        x = self.conv3(x)
        x = F.leaky_relu(self.batch3(x),0.2)
        x = x.view(-1, self.conv_dim*4*4*4)
        
        x = self.fc(x)
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()
        
        self.conv_dim = conv_dim
        self.fc = nn.Linear(z_size,conv_dim*4*4*4)
        self.deconv1 = nn.ConvTranspose2d(conv_dim*4,conv_dim*2,4,stride=2,padding=1)
        self.batch1 = nn.BatchNorm2d(conv_dim*2)
        self.deconv2 = nn.ConvTranspose2d(conv_dim*2,conv_dim,4,stride=2,padding=1)
        self.batch2 = nn.BatchNorm2d(conv_dim)
        self.deconv3 = nn.ConvTranspose2d(conv_dim,3,4,stride=2,padding=1)
        # complete init function
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        x = self.fc(x)
        x = x.view(-1,self.conv_dim*4,4,4)
        x = self.deconv1(x)
        x = F.leaky_relu(self.batch1(x),0.2)
        x = self.deconv2(x)
        x = F.leaky_relu(self.batch2(x),0.2)
        x = self.deconv3(x)
        
        x = F.tanh(x)
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
from torch.nn import init
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
        init.normal_(m.weight.data, 0.0, 0.2)
    
    elif classname.find('BatchNorm2d') != -1:  # BatchNorm Layer's weight is not a matrix; only normal distribution applies.
            init.normal_(m.weight.data, 1.0, 0.2)
            init.constant_(m.bias.data, 0.0)
    # TODO: Apply initial weights to convolutional and linear layers

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (batch2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (batch3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (deconv1): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (batch1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv2): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (batch2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv3): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    
    return torch.mean((D_out-1)**2)

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''

    return torch.mean(D_out-1**2)

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

# Create optimizers for the discriminator D and generator G
lr = 0.0002
beta1= 0.5
beta2= 0.999
d_optimizer = optim.Adam(D.parameters(),lr,[beta1,beta2])
g_optimizer = optim.Adam(G.parameters(),lr,[beta1,beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            d_optimizer.zero_grad()
            if train_on_gpu:
                real_images = real_images.cuda()
            D_real = D(real_images)
            d_real_loss = real_loss(D_real)
            

            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float() 
            
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)
            
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)
            
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()
                
            # 2. Train the generator with an adversarial loss
            
            g_optimizer.zero_grad()
            
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)

            D_fake = D(fake_images)
            g_loss = real_loss(D_fake) # use real loss to flip labels
        
            # perform backprop
            g_loss.backward()
            g_optimizer.step()
                
                
                
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 30


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   30] | d_loss: -1.9157 | g_loss: 24.2940
# Epoch [    1/   30] | d_loss: -3.0498 | g_loss: 30.3640
# Epoch [    1/   30] | d_loss: -1.6424 | g_loss: 17.8874
# Epoch [    1/   30] | d_loss: -0.3223 | g_loss: 10.4692
# Epoch [    1/   30] | d_loss: 4.9651 | g_loss: 11.0141
# Epoch [    1/   30] | d_loss: -2.2723 | g_loss: 13.7513
# Epoch [    1/   30] | d_loss: -1.5218 | g_loss: 15.7965
# Epoch [    1/   30] | d_loss: 0.5861 | g_loss: 16.8470
# Epoch [    1/   30] | d_loss: -1.4850 | g_loss: 18.4696
# Epoch [    1/   30] | d_loss: -0.6451 | g_loss: 18.8935
# Epoch [    1/   30] | d_loss: -1.3920 | g_loss: 18.2104
# Epoch [    1/   30] | d_loss: -0.3345 | g_loss: 12.0861
# Epoch [    1/   30] | d_loss: 0.4426 | g_loss: 12.0650
# Epoch [    1/   30] | d_loss: 0.3587 | g_loss: 11.2233
# Epoch [    1/   30] | d_loss: -1.1062 | g_loss: 10.2310
# Epoch [    2/   30] | d_loss: -1.1241 | g_loss: 9.9514
# Epoch [    2/   30] | d_loss: 2.7126 | g_loss: 6.0857
# Epoch [    2/   30] | d_loss: -0.5412 | g_loss: 8.1091
# Epoch [    2/   30] | d_loss: -1.1676 | g_loss: 8.5818
# Epoch [    2/   30] | d_loss: -1.3329 | g_loss: 17.4674
# Epoch [    2/   30] | d_loss: -2.0184 | g_loss: 14.7702
# Epoch [    2/   30] | d_loss: -0.5980 | g_loss: 16.2715
# Epoch [    2/   30] | d_loss: 1.9612 | g_loss: 3.6395
# Epoch [    2/   30] | d_loss: 0.2697 | g_loss: 6.9422
# Epoch [    2/   30] | d_loss: -0.2318 | g_loss: 6.0586
# Epoch [    2/   30] | d_loss: 1.8111 | g_loss: 4.0151
# Epoch [    2/   30] | d_loss: 0.2081 | g_loss: 3.8297
# Epoch [    2/   30] | d_loss: -1.1499 | g_loss: 12.4392
# Epoch [    2/   30] | d_loss: -0.3492 | g_loss: 8.5492
# Epoch [    2/   30] | d_loss: -0.3446 | g_loss: 8.0977
# Epoch [    3/   30] | d_loss: 0.7603 | g_loss: 9.4170
# Epoch [    3/   30] | d_loss: -0.1911 | g_loss: 1.5128
# Epoch [    3/   30] | d_loss: 0.9270 | g_loss: 1.9103
# Epoch [    3/   30] | d_loss: -0.5976 | g_loss: 7.2476
# Epoch [    3/   30] | d_loss: -0.3852 | g_loss: 3.5809
# Epoch [    3/   30] | d_loss: 0.3193 | g_loss: 6.3274
# Epoch [    3/   30] | d_loss: -0.3877 | g_loss: 5.0000
# Epoch [    3/   30] | d_loss: -1.2300 | g_loss: 10.1454
# Epoch [    3/   30] | d_loss: -0.3083 | g_loss: 5.9883
# Epoch [    3/   30] | d_loss: 0.6147 | g_loss: 7.8062
# Epoch [    3/   30] | d_loss: -1.0936 | g_loss: 4.7309
# Epoch [    3/   30] | d_loss: -0.0996 | g_loss: 3.5918
# Epoch [    3/   30] | d_loss: -0.4957 | g_loss: 4.0654
# Epoch [    3/   30] | d_loss: -1.1939 | g_loss: 7.9324
# Epoch [    3/   30] | d_loss: 1.1474 | g_loss: 4.4362
# Epoch [    4/   30] | d_loss: 2.1846 | g_loss: 2.1830
# Epoch [    4/   30] | d_loss: -0.4872 | g_loss: 5.3466
# Epoch [    4/   30] | d_loss: -0.4031 | g_loss: 3.9180
# Epoch [    4/   30] | d_loss: -0.0852 | g_loss: 4.0118
# Epoch [    4/   30] | d_loss: -1.0704 | g_loss: 5.1936
# Epoch [    4/   30] | d_loss: -1.2639 | g_loss: 8.5329
# Epoch [    4/   30] | d_loss: 0.0382 | g_loss: 2.6167
# Epoch [    4/   30] | d_loss: -0.5295 | g_loss: 5.1087
# Epoch [    4/   30] | d_loss: 0.1109 | g_loss: 4.3534
# Epoch [    4/   30] | d_loss: -0.1501 | g_loss: 3.6041
# Epoch [    4/   30] | d_loss: -0.2649 | g_loss: 2.5809
# Epoch [    4/   30] | d_loss: -0.4304 | g_loss: 4.7823
# Epoch [    4/   30] | d_loss: -0.5317 | g_loss: 4.2438
# Epoch [    4/   30] | d_loss: -0.1547 | g_loss: 3.5008
# Epoch [    4/   30] | d_loss: 0.0883 | g_loss: 1.1358
# Epoch [    5/   30] | d_loss: -0.5216 | g_loss: 3.3382
# Epoch [    5/   30] | d_loss: -0.0812 | g_loss: 3.1095
# Epoch [    5/   30] | d_loss: -0.8250 | g_loss: 6.2754
# Epoch [    5/   30] | d_loss: 0.1858 | g_loss: 4.1044
# Epoch [    5/   30] | d_loss: 0.6145 | g_loss: 1.7152
# Epoch [    5/   30] | d_loss: -0.6206 | g_loss: 4.2983
# Epoch [    5/   30] | d_loss: -1.3602 | g_loss: 11.7938
# Epoch [    5/   30] | d_loss: -0.5185 | g_loss: 4.6073
# Epoch [    5/   30] | d_loss: 0.2631 | g_loss: 2.4750
# Epoch [    5/   30] | d_loss: -0.2953 | g_loss: 2.0641
# Epoch [    5/   30] | d_loss: -0.0041 | g_loss: 2.2913
# Epoch [    5/   30] | d_loss: -0.4793 | g_loss: 5.3536
# Epoch [    5/   30] | d_loss: 0.3666 | g_loss: 2.8300
# Epoch [    5/   30] | d_loss: -0.1634 | g_loss: 3.2518
# Epoch [    5/   30] | d_loss: -0.4565 | g_loss: 3.4162
# Epoch [    6/   30] | d_loss: -0.5491 | g_loss: 5.3825
# Epoch [    6/   30] | d_loss: -0.8134 | g_loss: 3.5601
# Epoch [    6/   30] | d_loss: -0.2959 | g_loss: 6.1109
# Epoch [    6/   30] | d_loss: 0.1250 | g_loss: 3.1927
# Epoch [    6/   30] | d_loss: -0.2454 | g_loss: 2.9790
# Epoch [    6/   30] | d_loss: 0.2207 | g_loss: 1.3616
# Epoch [    6/   30] | d_loss: -0.7042 | g_loss: 4.6261
# Epoch [    6/   30] | d_loss: -0.2752 | g_loss: 2.4544
# Epoch [    6/   30] | d_loss: -0.1613 | g_loss: 1.0301
# Epoch [    6/   30] | d_loss: 0.1078 | g_loss: 1.9256
# Epoch [    6/   30] | d_loss: -0.0179 | g_loss: 1.8568
# Epoch [    6/   30] | d_loss: -0.5472 | g_loss: 3.4968
# Epoch [    6/   30] | d_loss: -0.2687 | g_loss: 2.0339
# Epoch [    6/   30] | d_loss: 0.2303 | g_loss: 1.6947
# Epoch [    6/   30] | d_loss: -0.0207 | g_loss: 1.8214
# Epoch [    7/   30] | d_loss: -0.0260 | g_loss: 2.5955
# Epoch [    7/   30] | d_loss: -0.7956 | g_loss: 3.2301
# Epoch [    7/   30] | d_loss: -0.1712 | g_loss: 1.6937
# Epoch [    7/   30] | d_loss: 0.0238 | g_loss: 1.6155
# Epoch [    7/   30] | d_loss: -0.0197 | g_loss: 1.3687
# Epoch [    7/   30] | d_loss: -0.1711 | g_loss: 3.4333
# Epoch [    7/   30] | d_loss: -0.4642 | g_loss: 3.2629
# Epoch [    7/   30] | d_loss: -0.1025 | g_loss: 1.3556
# Epoch [    7/   30] | d_loss: -0.5048 | g_loss: 2.3455
# Epoch [    7/   30] | d_loss: 0.1991 | g_loss: 1.6253
# Epoch [    7/   30] | d_loss: -0.4608 | g_loss: 3.7490
# Epoch [    7/   30] | d_loss: 0.1757 | g_loss: 1.1090
# Epoch [    7/   30] | d_loss: -0.2540 | g_loss: 4.3864
# Epoch [    7/   30] | d_loss: 0.6976 | g_loss: 1.1027
# Epoch [    7/   30] | d_loss: -0.0603 | g_loss: 1.5115
# Epoch [    8/   30] | d_loss: 0.9098 | g_loss: 1.4814
# Epoch [    8/   30] | d_loss: -0.1177 | g_loss: 1.4900
# Epoch [    8/   30] | d_loss: 0.1453 | g_loss: 1.2211
# Epoch [    8/   30] | d_loss: -0.2039 | g_loss: 1.6088
# Epoch [    8/   30] | d_loss: -0.0445 | g_loss: 2.4290
# Epoch [    8/   30] | d_loss: -0.1910 | g_loss: 2.6290
# Epoch [    8/   30] | d_loss: -0.2220 | g_loss: 1.4865
# Epoch [    8/   30] | d_loss: 0.2154 | g_loss: 1.2106
# Epoch [    8/   30] | d_loss: 0.0530 | g_loss: 1.1470
# Epoch [    8/   30] | d_loss: -0.1448 | g_loss: 1.4471
# Epoch [    8/   30] | d_loss: -0.2344 | g_loss: 1.4351
# Epoch [    8/   30] | d_loss: 0.2594 | g_loss: 0.7450
# Epoch [    8/   30] | d_loss: -0.0597 | g_loss: 1.0612
# Epoch [    8/   30] | d_loss: -0.0385 | g_loss: 1.3890
# Epoch [    8/   30] | d_loss: -0.1347 | g_loss: 1.3522
# Epoch [    9/   30] | d_loss: -0.1693 | g_loss: 1.5328
# Epoch [    9/   30] | d_loss: 0.2706 | g_loss: 1.1254
# Epoch [    9/   30] | d_loss: 0.4024 | g_loss: 0.4656
# Epoch [    9/   30] | d_loss: -0.1973 | g_loss: 0.8486
# Epoch [    9/   30] | d_loss: -0.0385 | g_loss: 1.3178
# Epoch [    9/   30] | d_loss: 0.0986 | g_loss: 0.8638
# Epoch [    9/   30] | d_loss: 0.3568 | g_loss: 0.4589
# Epoch [    9/   30] | d_loss: -0.0649 | g_loss: 1.7964
# Epoch [    9/   30] | d_loss: -0.2082 | g_loss: 1.3032
# Epoch [    9/   30] | d_loss: -0.5004 | g_loss: 3.3502
# Epoch [    9/   30] | d_loss: -0.0348 | g_loss: 1.8561
# Epoch [    9/   30] | d_loss: -0.0194 | g_loss: 0.6770
# Epoch [    9/   30] | d_loss: -0.3092 | g_loss: 1.9131
# Epoch [    9/   30] | d_loss: -0.1880 | g_loss: 1.4256
# Epoch [    9/   30] | d_loss: -0.1585 | g_loss: 1.8467
# Epoch [   10/   30] | d_loss: -0.4930 | g_loss: 1.6984
# Epoch [   10/   30] | d_loss: -0.2604 | g_loss: 1.0417
# Epoch [   10/   30] | d_loss: -0.1831 | g_loss: 1.5639
# Epoch [   10/   30] | d_loss: -0.6005 | g_loss: 1.8612
# Epoch [   10/   30] | d_loss: 0.1269 | g_loss: 1.1726
# Epoch [   10/   30] | d_loss: -0.1656 | g_loss: 0.8399
# Epoch [   10/   30] | d_loss: -0.0920 | g_loss: 0.7935
# Epoch [   10/   30] | d_loss: 0.0131 | g_loss: 1.3204
# Epoch [   10/   30] | d_loss: -0.3241 | g_loss: 1.0252
# Epoch [   10/   30] | d_loss: -0.1626 | g_loss: 1.1204
# Epoch [   10/   30] | d_loss: -0.0401 | g_loss: 1.6498
# Epoch [   10/   30] | d_loss: -0.2985 | g_loss: 1.2640
# Epoch [   10/   30] | d_loss: 0.1228 | g_loss: 0.9281
# Epoch [   10/   30] | d_loss: -0.1330 | g_loss: 0.4649
# Epoch [   10/   30] | d_loss: -0.5010 | g_loss: 1.1653
# Epoch [   11/   30] | d_loss: 0.2995 | g_loss: 0.8186
# Epoch [   11/   30] | d_loss: -0.2593 | g_loss: 1.3640
# Epoch [   11/   30] | d_loss: -0.2519 | g_loss: 1.4311
# Epoch [   11/   30] | d_loss: -0.3660 | g_loss: 1.8316
# Epoch [   11/   30] | d_loss: -0.2348 | g_loss: 0.9143
# Epoch [   11/   30] | d_loss: -0.1328 | g_loss: 0.7498
# Epoch [   11/   30] | d_loss: -0.2185 | g_loss: 0.6720
# Epoch [   11/   30] | d_loss: 0.0353 | g_loss: 0.5046
# Epoch [   11/   30] | d_loss: -0.2495 | g_loss: 1.6095
# Epoch [   11/   30] | d_loss: -0.2125 | g_loss: 0.4294
# Epoch [   11/   30] | d_loss: -0.3372 | g_loss: 1.1481
# Epoch [   11/   30] | d_loss: -0.2659 | g_loss: 0.6395
# Epoch [   11/   30] | d_loss: -0.2730 | g_loss: 1.1738
# Epoch [   11/   30] | d_loss: -0.3902 | g_loss: 1.2037
# Epoch [   11/   30] | d_loss: -0.2250 | g_loss: 0.8133
# Epoch [   12/   30] | d_loss: -0.1294 | g_loss: 0.6689
# Epoch [   12/   30] | d_loss: 0.0238 | g_loss: 0.4743
# Epoch [   12/   30] | d_loss: -0.0861 | g_loss: 0.5986
# Epoch [   12/   30] | d_loss: -0.1354 | g_loss: 0.9597
# Epoch [   12/   30] | d_loss: -0.0881 | g_loss: 0.4671
# Epoch [   12/   30] | d_loss: -0.3962 | g_loss: 1.5837
# Epoch [   12/   30] | d_loss: -0.3917 | g_loss: 1.3882
# Epoch [   12/   30] | d_loss: -0.2128 | g_loss: 0.5568
# Epoch [   12/   30] | d_loss: -0.2322 | g_loss: 1.1428
# Epoch [   12/   30] | d_loss: -0.0775 | g_loss: 0.4855
# Epoch [   12/   30] | d_loss: -0.1908 | g_loss: 0.6211
# Epoch [   12/   30] | d_loss: -0.1367 | g_loss: 0.4777
# Epoch [   12/   30] | d_loss: -0.2499 | g_loss: 1.0486
# Epoch [   12/   30] | d_loss: -0.2269 | g_loss: 0.8847
# Epoch [   12/   30] | d_loss: -0.1841 | g_loss: 0.7890
# Epoch [   13/   30] | d_loss: -0.2516 | g_loss: 0.9769
# Epoch [   13/   30] | d_loss: 0.3186 | g_loss: 1.0167
# Epoch [   13/   30] | d_loss: -0.1675 | g_loss: 0.5524
# Epoch [   13/   30] | d_loss: -0.0912 | g_loss: 0.3521
# Epoch [   13/   30] | d_loss: -0.0060 | g_loss: 0.6407
# Epoch [   13/   30] | d_loss: -0.4013 | g_loss: 1.3851
# Epoch [   13/   30] | d_loss: -0.2237 | g_loss: 0.8996
# Epoch [   13/   30] | d_loss: -0.1150 | g_loss: 0.5320
# Epoch [   13/   30] | d_loss: -0.1309 | g_loss: 0.7452
# Epoch [   13/   30] | d_loss: -0.4483 | g_loss: 1.8780
# Epoch [   13/   30] | d_loss: -0.3543 | g_loss: 1.1544
# Epoch [   13/   30] | d_loss: -0.2809 | g_loss: 0.8422
# Epoch [   13/   30] | d_loss: -0.3838 | g_loss: 1.2860
# Epoch [   13/   30] | d_loss: -0.2948 | g_loss: 1.2722
# Epoch [   13/   30] | d_loss: -0.0968 | g_loss: 0.6003
# Epoch [   14/   30] | d_loss: -0.4991 | g_loss: 1.1654
# Epoch [   14/   30] | d_loss: -0.4307 | g_loss: 1.1763
# Epoch [   14/   30] | d_loss: -0.2967 | g_loss: 0.8036
# Epoch [   14/   30] | d_loss: -0.3218 | g_loss: 0.8432
# Epoch [   14/   30] | d_loss: -0.0287 | g_loss: 0.5537
# Epoch [   14/   30] | d_loss: -0.1890 | g_loss: 0.5198
# Epoch [   14/   30] | d_loss: -0.1080 | g_loss: 0.8345
# Epoch [   14/   30] | d_loss: -0.2535 | g_loss: 1.1810
# Epoch [   14/   30] | d_loss: -0.1665 | g_loss: 0.5880
# Epoch [   14/   30] | d_loss: -0.3273 | g_loss: 1.2535
# Epoch [   14/   30] | d_loss: -0.0581 | g_loss: 0.9037
# Epoch [   14/   30] | d_loss: -0.3612 | g_loss: 0.9045
# Epoch [   14/   30] | d_loss: -0.3878 | g_loss: 1.0201
# Epoch [   14/   30] | d_loss: -0.2666 | g_loss: 0.9665
# Epoch [   14/   30] | d_loss: -0.3602 | g_loss: 0.7686
# Epoch [   15/   30] | d_loss: -0.1512 | g_loss: 0.6386
# Epoch [   15/   30] | d_loss: -0.3087 | g_loss: 0.7640
# Epoch [   15/   30] | d_loss: -0.2111 | g_loss: 0.4598
# Epoch [   15/   30] | d_loss: -0.1268 | g_loss: 1.1572
# Epoch [   15/   30] | d_loss: -0.2212 | g_loss: 0.5694
# Epoch [   15/   30] | d_loss: -0.2417 | g_loss: 0.7311
# Epoch [   15/   30] | d_loss: -0.1523 | g_loss: 0.8145
# Epoch [   15/   30] | d_loss: -0.0992 | g_loss: 0.4860
# Epoch [   15/   30] | d_loss: -0.2163 | g_loss: 0.5024
# Epoch [   15/   30] | d_loss: -0.3339 | g_loss: 0.8642
# Epoch [   15/   30] | d_loss: -0.2515 | g_loss: 0.8726
# Epoch [   15/   30] | d_loss: -0.0620 | g_loss: 0.8927
# Epoch [   15/   30] | d_loss: -0.2231 | g_loss: 0.8520
# Epoch [   15/   30] | d_loss: -0.1805 | g_loss: 0.5754
# Epoch [   15/   30] | d_loss: -0.1353 | g_loss: 0.7246
# Epoch [   16/   30] | d_loss: -0.3341 | g_loss: 0.8198
# Epoch [   16/   30] | d_loss: -0.1875 | g_loss: 0.3382
# Epoch [   16/   30] | d_loss: -0.3527 | g_loss: 0.6386
# Epoch [   16/   30] | d_loss: -0.4286 | g_loss: 1.2472
# Epoch [   16/   30] | d_loss: -0.2873 | g_loss: 0.9986
# Epoch [   16/   30] | d_loss: -0.3567 | g_loss: 1.0036
# Epoch [   16/   30] | d_loss: -0.1905 | g_loss: 0.5535
# Epoch [   16/   30] | d_loss: -0.2553 | g_loss: 1.0826
# Epoch [   16/   30] | d_loss: -0.4607 | g_loss: 0.8548
# Epoch [   16/   30] | d_loss: -0.3239 | g_loss: 0.5755
# Epoch [   16/   30] | d_loss: -0.1452 | g_loss: 0.5595
# Epoch [   16/   30] | d_loss: -0.2426 | g_loss: 0.5126
# Epoch [   16/   30] | d_loss: -0.4466 | g_loss: 0.8245
# Epoch [   16/   30] | d_loss: -0.2588 | g_loss: 0.7972
# Epoch [   16/   30] | d_loss: -0.1386 | g_loss: 0.5126
# Epoch [   17/   30] | d_loss: -0.3687 | g_loss: 1.0709
# Epoch [   17/   30] | d_loss: -0.1702 | g_loss: 0.7145
# Epoch [   17/   30] | d_loss: -0.2267 | g_loss: 0.6540
# Epoch [   17/   30] | d_loss: -0.1251 | g_loss: 0.4841
# Epoch [   17/   30] | d_loss: -0.2562 | g_loss: 0.9686
# Epoch [   17/   30] | d_loss: -0.2708 | g_loss: 0.7219
# Epoch [   17/   30] | d_loss: -0.4587 | g_loss: 1.3036
# Epoch [   17/   30] | d_loss: -0.3603 | g_loss: 0.8748
# Epoch [   17/   30] | d_loss: -0.4542 | g_loss: 0.9915
# Epoch [   17/   30] | d_loss: -0.1845 | g_loss: 0.8265
# Epoch [   17/   30] | d_loss: 0.0593 | g_loss: 0.7734
# Epoch [   17/   30] | d_loss: -0.1697 | g_loss: 1.0512
# Epoch [   17/   30] | d_loss: -0.3040 | g_loss: 0.6695
# Epoch [   17/   30] | d_loss: -0.4565 | g_loss: 0.8697
# Epoch [   17/   30] | d_loss: -0.4834 | g_loss: 1.1527
# Epoch [   18/   30] | d_loss: -0.1481 | g_loss: 0.3247
# Epoch [   18/   30] | d_loss: -0.3226 | g_loss: 0.6217
# Epoch [   18/   30] | d_loss: -0.1601 | g_loss: 0.7909
# Epoch [   18/   30] | d_loss: -0.3378 | g_loss: 1.3674
# Epoch [   18/   30] | d_loss: -0.0357 | g_loss: 0.4809
# Epoch [   18/   30] | d_loss: -0.6053 | g_loss: 1.8866
# Epoch [   18/   30] | d_loss: -0.4652 | g_loss: 1.2889
# Epoch [   18/   30] | d_loss: -0.5200 | g_loss: 1.6055
# Epoch [   18/   30] | d_loss: -0.3911 | g_loss: 1.0386
# Epoch [   18/   30] | d_loss: -0.4768 | g_loss: 1.0428
# Epoch [   18/   30] | d_loss: -0.4002 | g_loss: 0.9776
# Epoch [   18/   30] | d_loss: -0.2554 | g_loss: 0.7286
# Epoch [   18/   30] | d_loss: -0.4559 | g_loss: 1.3171
# Epoch [   18/   30] | d_loss: -0.1863 | g_loss: 0.6213
# Epoch [   18/   30] | d_loss: -0.5701 | g_loss: 1.2261
# Epoch [   19/   30] | d_loss: -0.3029 | g_loss: 0.7212
# Epoch [   19/   30] | d_loss: -0.0735 | g_loss: 0.7390
# Epoch [   19/   30] | d_loss: -0.2347 | g_loss: 0.7752
# Epoch [   19/   30] | d_loss: -0.2986 | g_loss: 0.8392
# Epoch [   19/   30] | d_loss: -0.4296 | g_loss: 0.3500
# Epoch [   19/   30] | d_loss: -0.2941 | g_loss: 1.1132
# Epoch [   19/   30] | d_loss: -0.2168 | g_loss: 0.3420
# Epoch [   19/   30] | d_loss: -0.2800 | g_loss: 1.1180
# Epoch [   19/   30] | d_loss: -0.4502 | g_loss: 1.0540
# Epoch [   19/   30] | d_loss: -0.3449 | g_loss: 0.5317
# Epoch [   19/   30] | d_loss: -0.3151 | g_loss: 1.4979
# Epoch [   19/   30] | d_loss: 0.1348 | g_loss: 0.7444
# Epoch [   19/   30] | d_loss: -0.2762 | g_loss: 0.6410
# Epoch [   21/   30] | d_loss: -0.2939 | g_loss: 1.0570
# Epoch [   21/   30] | d_loss: -0.2238 | g_loss: 0.3573
# Epoch [   21/   30] | d_loss: -0.3627 | g_loss: 0.8119
# Epoch [   21/   30] | d_loss: -0.2317 | g_loss: 0.6896
# Epoch [   21/   30] | d_loss: -0.3799 | g_loss: 0.5806
# Epoch [   21/   30] | d_loss: -0.4615 | g_loss: 0.8509
# Epoch [   21/   30] | d_loss: -0.3985 | g_loss: 1.2988
# Epoch [   21/   30] | d_loss: -0.6502 | g_loss: 1.7565
# Epoch [   21/   30] | d_loss: 0.0172 | g_loss: 0.4809
# Epoch [   21/   30] | d_loss: -0.4085 | g_loss: 1.1045
# Epoch [   21/   30] | d_loss: -0.3045 | g_loss: 0.7324
# Epoch [   21/   30] | d_loss: -0.4072 | g_loss: 0.8445
# Epoch [   21/   30] | d_loss: -0.1631 | g_loss: 0.9070
# Epoch [   22/   30] | d_loss: -0.3736 | g_loss: 0.5625
# Epoch [   22/   30] | d_loss: -0.3528 | g_loss: 0.7695
# Epoch [   22/   30] | d_loss: -0.2399 | g_loss: 0.4069
# Epoch [   22/   30] | d_loss: -0.3064 | g_loss: 0.7455
# Epoch [   22/   30] | d_loss: -0.0877 | g_loss: 0.5480
# Epoch [   22/   30] | d_loss: -0.4443 | g_loss: 0.6968
# Epoch [   22/   30] | d_loss: -0.2247 | g_loss: 0.3783
# Epoch [   22/   30] | d_loss: -0.3627 | g_loss: 0.8532
# Epoch [   22/   30] | d_loss: -0.2762 | g_loss: 0.3689
# Epoch [   22/   30] | d_loss: -0.4431 | g_loss: 0.8876
# Epoch [   22/   30] | d_loss: -0.5027 | g_loss: 0.9602
# Epoch [   22/   30] | d_loss: -0.5904 | g_loss: 1.0842
# Epoch [   22/   30] | d_loss: -0.0997 | g_loss: 0.8272
# Epoch [   22/   30] | d_loss: -0.3501 | g_loss: 0.7147
# Epoch [   22/   30] | d_loss: -0.3650 | g_loss: 0.6335
# Epoch [   23/   30] | d_loss: -0.3416 | g_loss: 1.0413
# Epoch [   23/   30] | d_loss: -0.0495 | g_loss: 0.4758
# Epoch [   23/   30] | d_loss: -0.5374 | g_loss: 1.0654
# Epoch [   23/   30] | d_loss: -0.2981 | g_loss: 0.4799
# Epoch [   23/   30] | d_loss: -0.3004 | g_loss: 0.9255
# Epoch [   23/   30] | d_loss: -0.0951 | g_loss: 0.4758
# Epoch [   23/   30] | d_loss: -0.4388 | g_loss: 0.5898
# Epoch [   23/   30] | d_loss: -0.5280 | g_loss: 1.3129
# Epoch [   23/   30] | d_loss: -0.2276 | g_loss: 0.7236
# Epoch [   23/   30] | d_loss: -0.2054 | g_loss: 0.6329
# Epoch [   23/   30] | d_loss: -0.3317 | g_loss: 0.4873
# Epoch [   23/   30] | d_loss: -0.2782 | g_loss: 0.5365
# Epoch [   23/   30] | d_loss: -0.3696 | g_loss: 0.6016
# Epoch [   23/   30] | d_loss: -0.1205 | g_loss: 0.6529
# Epoch [   23/   30] | d_loss: -0.3018 | g_loss: 0.6149
# Epoch [   24/   30] | d_loss: -0.2442 | g_loss: 0.9923
# Epoch [   24/   30] | d_loss: -0.3074 | g_loss: 1.0736
# Epoch [   24/   30] | d_loss: -0.1340 | g_loss: 0.5137
# Epoch [   24/   30] | d_loss: -0.3193 | g_loss: 0.5416
# Epoch [   24/   30] | d_loss: -0.5411 | g_loss: 1.2392
# Epoch [   24/   30] | d_loss: -0.4156 | g_loss: 1.1547
# Epoch [   24/   30] | d_loss: -0.2645 | g_loss: 0.8403
# Epoch [   24/   30] | d_loss: -0.3025 | g_loss: 1.1939
# Epoch [   24/   30] | d_loss: -0.1883 | g_loss: 1.3950
# Epoch [   24/   30] | d_loss: -0.4392 | g_loss: 1.1588
# Epoch [   24/   30] | d_loss: -0.3166 | g_loss: 1.0213
# Epoch [   24/   30] | d_loss: -0.4472 | g_loss: 1.0112
# Epoch [   24/   30] | d_loss: -0.2902 | g_loss: 0.7193
# Epoch [   24/   30] | d_loss: -0.0262 | g_loss: 0.3842
# Epoch [   24/   30] | d_loss: 0.2766 | g_loss: 0.9647
# Epoch [   25/   30] | d_loss: -0.4472 | g_loss: 1.4307
# Epoch [   25/   30] | d_loss: -0.2957 | g_loss: 0.8364
# Epoch [   25/   30] | d_loss: -0.7897 | g_loss: 1.3116
# Epoch [   25/   30] | d_loss: -0.4356 | g_loss: 0.8741
# Epoch [   25/   30] | d_loss: -0.4944 | g_loss: 1.1167
# Epoch [   25/   30] | d_loss: -0.0442 | g_loss: 0.5750
# Epoch [   25/   30] | d_loss: -0.2859 | g_loss: 0.6104
# Epoch [   25/   30] | d_loss: -0.1668 | g_loss: 0.8069
# Epoch [   25/   30] | d_loss: -0.4832 | g_loss: 1.1225
# Epoch [   25/   30] | d_loss: -0.4611 | g_loss: 1.0462
# Epoch [   25/   30] | d_loss: -0.3342 | g_loss: 0.7871
# Epoch [   25/   30] | d_loss: -0.1694 | g_loss: 0.4658
# Epoch [   25/   30] | d_loss: -0.4060 | g_loss: 0.5702
# Epoch [   25/   30] | d_loss: -0.2979 | g_loss: 0.4178
# Epoch [   25/   30] | d_loss: -0.4433 | g_loss: 0.9616
# Epoch [   26/   30] | d_loss: -0.3738 | g_loss: 1.1302
# Epoch [   26/   30] | d_loss: -0.4303 | g_loss: 0.7275
# Epoch [   26/   30] | d_loss: -0.3836 | g_loss: 0.7613
# Epoch [   26/   30] | d_loss: -0.2852 | g_loss: 0.4437
# Epoch [   26/   30] | d_loss: -0.3540 | g_loss: 0.5412
# Epoch [   26/   30] | d_loss: -0.1904 | g_loss: 0.5244
# Epoch [   26/   30] | d_loss: -0.2551 | g_loss: 0.6171
# Epoch [   26/   30] | d_loss: 0.1655 | g_loss: 0.7099
# Epoch [   26/   30] | d_loss: -0.5328 | g_loss: 0.9453
# Epoch [   26/   30] | d_loss: -0.4280 | g_loss: 0.7609
# Epoch [   26/   30] | d_loss: -0.5019 | g_loss: 1.2981
# Epoch [   26/   30] | d_loss: -0.3691 | g_loss: 0.6049
# Epoch [   26/   30] | d_loss: -0.3403 | g_loss: 0.6864
# Epoch [   26/   30] | d_loss: -0.2197 | g_loss: 0.5336
# Epoch [   26/   30] | d_loss: -0.3901 | g_loss: 1.4461
# Epoch [   27/   30] | d_loss: -0.7636 | g_loss: 3.2794
# Epoch [   27/   30] | d_loss: -0.5091 | g_loss: 1.3786
# Epoch [   27/   30] | d_loss: -0.4008 | g_loss: 0.7023
# Epoch [   27/   30] | d_loss: -0.2816 | g_loss: 0.7103
# Epoch [   27/   30] | d_loss: -0.4514 | g_loss: 1.2403
# Epoch [   27/   30] | d_loss: -0.5365 | g_loss: 1.3758
# Epoch [   27/   30] | d_loss: -0.6835 | g_loss: 1.3285
# Epoch [   27/   30] | d_loss: -0.4712 | g_loss: 1.4645
# Epoch [   27/   30] | d_loss: 1.1641 | g_loss: 0.2147
# Epoch [   27/   30] | d_loss: -0.2933 | g_loss: 0.9478
# Epoch [   27/   30] | d_loss: -0.3802 | g_loss: 0.9881
# Epoch [   27/   30] | d_loss: -0.3829 | g_loss: 0.5256
# Epoch [   27/   30] | d_loss: -0.4665 | g_loss: 2.5103
# Epoch [   27/   30] | d_loss: -0.3956 | g_loss: 1.1242
# Epoch [   27/   30] | d_loss: -0.3004 | g_loss: 1.6062
# Epoch [   28/   30] | d_loss: -0.4441 | g_loss: 0.7544
# Epoch [   28/   30] | d_loss: -0.4913 | g_loss: 1.2500
# Epoch [   28/   30] | d_loss: -0.2976 | g_loss: 0.3143
# Epoch [   28/   30] | d_loss: -0.4934 | g_loss: 1.1293
# Epoch [   28/   30] | d_loss: -0.2205 | g_loss: 0.6570
# Epoch [   28/   30] | d_loss: -0.6162 | g_loss: 1.0743
# Epoch [   28/   30] | d_loss: -0.2669 | g_loss: 0.6802
# Epoch [   28/   30] | d_loss: -0.5063 | g_loss: 0.7958
# Epoch [   28/   30] | d_loss: -0.3659 | g_loss: 0.7235
# Epoch [   28/   30] | d_loss: -0.4397 | g_loss: 0.7618
# Epoch [   28/   30] | d_loss: -0.5677 | g_loss: 1.5940
# Epoch [   28/   30] | d_loss: -0.4435 | g_loss: 1.5200
# Epoch [   28/   30] | d_loss: -0.0535 | g_loss: 0.7865
# Epoch [   28/   30] | d_loss: 0.3006 | g_loss: 0.4745
# Epoch [   28/   30] | d_loss: -0.1911 | g_loss: 0.8212
# Epoch [   29/   30] | d_loss: -0.6706 | g_loss: 2.0191
# Epoch [   29/   30] | d_loss: -0.5569 | g_loss: 0.8148
# Epoch [   29/   30] | d_loss: -0.3971 | g_loss: 1.0067
# Epoch [   29/   30] | d_loss: -0.2329 | g_loss: 0.7165
# Epoch [   29/   30] | d_loss: -0.2492 | g_loss: 0.4807
# Epoch [   29/   30] | d_loss: -0.3250 | g_loss: 0.8986
# Epoch [   29/   30] | d_loss: -0.4945 | g_loss: 1.0013
# Epoch [   29/   30] | d_loss: -0.2365 | g_loss: 0.4470
# Epoch [   29/   30] | d_loss: -0.2460 | g_loss: 1.8732
# Epoch [   29/   30] | d_loss: -0.3811 | g_loss: 0.9366
# Epoch [   29/   30] | d_loss: -0.4621 | g_loss: 1.1798
# Epoch [   29/   30] | d_loss: -0.4735 | g_loss: 0.8763
# Epoch [   29/   30] | d_loss: -0.4341 | g_loss: 0.9434
# Epoch [   29/   30] | d_loss: -0.1890 | g_loss: 0.6042
# Epoch [   29/   30] | d_loss: -0.3817 | g_loss: 0.5878
# Epoch [   30/   30] | d_loss: -0.4598 | g_loss: 0.5511
# Epoch [   30/   30] | d_loss: -0.3728 | g_loss: 1.3555
# Epoch [   30/   30] | d_loss: -0.5607 | g_loss: 0.6537
# Epoch [   30/   30] | d_loss: -0.6068 | g_loss: 1.1693
# Epoch [   30/   30] | d_loss: -0.5417 | g_loss: 1.2877
# Epoch [   30/   30] | d_loss: -0.2409 | g_loss: 0.6243
# Epoch [   30/   30] | d_loss: -0.4194 | g_loss: 0.8261
# Epoch [   30/   30] | d_loss: -0.2995 | g_loss: 0.5432
# Epoch [   30/   30] | d_loss: -0.4374 | g_loss: 1.3366
# Epoch [   30/   30] | d_loss: 1.8647 | g_loss: 1.3150
# Epoch [   30/   30] | d_loss: -0.4176 | g_loss: 0.9080
# Epoch [   30/   30] | d_loss: -0.6167 | g_loss: 1.7777
# Epoch [   30/   30] | d_loss: -0.6551 | g_loss: 1.3860
# Epoch [   30/   30] | d_loss: -0.8029 | g_loss: 3.0402
# Epoch [   30/   30] | d_loss: -0.1662 | g_loss: 0.8242

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:**
#
# The model has a lot of room for improvement. As mentioned above, the model was only trained with real photos of celebrities. These photos are disproportionally white. Since the DCGAN only generates photos similar to those in the training set, most of the generated photos are caucasian in apperance. One way to improve the models performance and have it generate a more realistic distribution of human faces is to train it on a more diverse and representative dataset of picture of human faces.
#
# The model does a pretty good job with the larger features of the human face, such as the hair line, and the position of the eyes, nose and mouth. However, it is not very good at generating the finer deteails of the nose, eyes and mouth. I thnk that a larger model with convolutional layers to serve as more fine feature detectors could help generate more realistic looking fine details in hte images.
#
# One thing that could improve this models performance could be the use of a different optimizier for the Descriminator model. While I used Adam for the Discriminator, other optimizers like SGD could be used and its hyperparameters tuned to get better performance. Lastly, increasing the number of epoch from 5 to 30 did not dramatically improve the performance. Unless more data is collected and the size of the model is incresed, I do not believe that addtional epochs of training would do much to improve performance.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
